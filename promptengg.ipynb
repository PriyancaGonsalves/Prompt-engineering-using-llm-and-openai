# %%
import os
os.environ["OPENAI_API_KEY"]="sk-7890abcdef7890abcdef7890abcdef7890abcd"

# %%
from langchain import PromptTemplate
template1 ='''I want you to act as a share market expert and advisor for people. In an easy way, explain the basics of {search_term} in one short line.'''

prompt=PromptTemplate(
    input_variables=['search_term'],
    template=template1
)

prompt.format(search_term='market price')
# Out:
# 'I want you to act as a share market expert and advisor for people. In an easy way, explain the basics of market price in one short line.'

# %%
# %pip install -qU langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.4 MB/s eta 0:00:00

# %%
from langchain_openai import OpenAI
from langchain.chains import LLMChain
llm = OpenAI(temperature=0.7)
chain1=LLMChain(llm=llm,prompt=prompt)

# %%
chain1.run('market capital')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-26-6be75417678f> in <cell line: 1>()
# ----> 1 chain1.run('market capital')
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
#     183
#     184         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     604             if len(args) != 1:
#     605                 raise ValueError("`run` supports only one positional argument.")
# --> 606             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607                 _output_key
# ...
